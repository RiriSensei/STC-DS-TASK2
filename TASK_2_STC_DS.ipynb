# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\kshri\\Downloads\\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#1
df.groupby(['race/ethnicity','gender']).mean(['math score','reading score','writing score'])
# Out:
#                        math score  reading score  writing score
# race/ethnicity gender
# group A        female   58.527778      69.000000      67.861111
#                male     63.735849      61.735849      59.150943
# group B        female   61.403846      71.076923      70.048077
#                male     65.930233      62.848837      60.220930
# group C        female   62.033333      71.944444      71.777778
#                male     67.611511      65.424460      62.712230
# group D        female   65.248062      74.046512      75.023256
#                male     69.413534      66.135338      65.413534
# group E        female   70.811594      75.840580      75.536232
#                male     76.746479      70.295775      67.394366

# %%
#2
#df1=df[(df['gender'=='male'])&(df['parental level of education']=="bachelor's degree")&(df['math score']>80)&(df['reading score']>85)]
#df.groupby(['gender'=='male','parental level of education'=="bachelor's degree"]).min(['math score'==80])
# WHY DO THE ABOVE PSEUDO CODES NOT WORK?????????????????????????
def task2():
    df1=(df.loc[(df['gender']=='male')&(df['parental level of education']=="bachelor's degree")&(df['math score']>80)&(df['reading score']>85)])
    display(df1)
    return (len(df1.index)/len(df.index))/100
task2()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 551   male        group B           bachelor's degree  free/reduced
# 562   male        group C           bachelor's degree      standard
# 571   male        group A           bachelor's degree      standard
# 612   male        group C           bachelor's degree      standard
# 916   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 551               completed          87             90             88
# 562               completed          96             90             92
# 571                    none          91             96             92
# 612               completed          94             90             91
# 916               completed         100            100            100
# 5e-05

# %%
#3
def task3():
    df1=(df.loc[((df['parental level of education']=='high school')|(df['parental level of education']=="bachelor's degree"))&(df['gender']=='male')&(df['race/ethnicity']=='group E')])
    display(df1)
    return len(df1.index)
task3()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 60    male        group E           bachelor's degree  free/reduced
# 137   male        group E                 high school      standard
# 186   male        group E                 high school      standard
# 197   male        group E                 high school  free/reduced
# 206   male        group E           bachelor's degree      standard
# 207   male        group E                 high school      standard
# 214   male        group E                 high school      standard
# 415   male        group E                 high school      standard
# 419   male        group E                 high school  free/reduced
# 476   male        group E           bachelor's degree      standard
# 538   male        group E           bachelor's degree      standard
# 592   male        group E           bachelor's degree      standard
# 757   male        group E           bachelor's degree  free/reduced
# ...

# %%
#4. gotta plot properly. not understanding which plot to use
def task4():
    df1=df.groupby('race/ethnicity').max()
    sns.pairplot(data=df1)
task4()

# %%
#5
def task5():
    sns.countplot(data=df,x='gender',hue='test preparation course')
task5()

# %%
#6
def task6():
    sns.pairplot(data=df,hue='gender')
task6()

# %%
#7 very confused
df1=df.corr()
sns.pairplot(df1)

# %%
#8 im not understanding how to plot three different score columns
sns.violinplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#9
def task9():
    sns.pairplot(data=df,hue='test preparation course')
task9()

# %%
#10. cannot quite make out the skewness
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>
